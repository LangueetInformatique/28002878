# %%
f = open("locations_corpus1.json")
liste1 = eval(f.read())
f.close()

f = open("locations_corpus2.json")
liste2 = eval(f.read())
f.close()

lieux1 = set(liste1)
lieux2 = set(liste2)

# %%
lieux_en_commun = lieux1.intersection(lieux2)
print("Intersection", len(lieux_en_commun))
print("dans lieux 1", len(lieux1.difference(lieux2)))
print("dans lieux 2", len(lieux2.difference(lieux1)))
# Out:
# Intersection 12
# dans lieux 1 34
# dans lieux 2 3144

# %%
freq1 = {}
for lieu in liste1:
  freq1.setdefault(lieu, 0)
  freq1[lieu]+=1

freq2 = {}
for lieu in liste2:
  freq2.setdefault(lieu, 0)
  freq2[lieu]+=1

# %%
print(freq2)
# Out:
# {'Voilà': 10, 'Pont': 30, 't’': 55, 'La-la-la': 5, 'la-la-la': 1, "J'ai allumé le feu": 1, 'Balayés': 1, 'Traîné': 1, 'Padam': 17, 'Souviens': 2, 'Écoutez': 15, 'Faut': 64, "J'": 156, 'I': 134, 'Old': 2, 'Jamais': 38, 'Les ongles': 2, 'Marie-Lou': 2, 'Dont': 14, 'Montmartre': 3, 'Tu': 16, 'Maintenant': 12, 'matin\nMontparnasse': 1, 'Café du Dôme\n': 1, 'Les Tuileries': 2, 'Paris': 71, 'Nothing': 1, 'Shout': 1, 'Evermore': 1, 'Empty heart': 1, 'Miners': 1, 'Upon': 1, 'Where': 1, 'Lovers': 1, 'Why should I': 1, 'Shall I': 1, 'Jérusalem': 4, 'Jérusalem\n\nDans Ses yeux': 2, 'Lui': 2, 'Jérusalem\n': 1, 'Jérusalem\n\nDans les yeux': 1, 'Jérusalem\nCar': 1, 'De Son cœur': 1, 'Village': 3, 'Dites': 10, 'Encore': 2, 'Protection': 1, 'Hélas': 4, 'Elle': 7, 'Ah': 17, 'Adieu': 34, 'Autrefois': 1, 'Laisse': 21, 'Viens': 22, 'Raisonne': 1, 'Parfois': 20, "J'avais peur de le voir sourire\n": 1, 'Montrant': 1, 'Chante': 15, 'A': 287, 'Johnny': 2, 'Tes': 18, 'Succès': 1, "J'ai des rires qui saignent": 1, 'Venez': 8, 'Bravo': 9, 'Nantes': 7, 'A boire': 2, 'Que demain vous mourrez\n\n': 1, 'la Loire': 1, 'Peut': 19, 'du Nord': 2, "J'ai compris": 4, 'Ardent': 1, "J'ai senti": 1, 'Simplement': 2, "J'aimais mon nouvel": 1, "J'aurais": 12, 'Que': 2, 'Ouvre': 1, 'Among': 1, 'Little': 2, 'Hallelujah': 4, 'Guide': 1, 'Beneath': 1, 'May': 1, 'A soul winged': 1, 'Emportant': 1, 'Morte': 2, "J'ai du fric": 1, 'Saint-Ouen': 2, 'Clignancourt': 3, 'Je': 16, 'Poulbots': 1, 'Moiti': 1, 'gros L': 1, 'Tandis': 10, 'Calmes': 1, 'Quelquefois': 6, 'Quel': 14, 'Comprends': 6, 'L?-l?-l': 1, 'Grand-mère': 2, 'Pleure': 9, 'Tais': 2, 'Raconte': 1, 'Pleure pas': 1, 'Pleure pas !': 1, 'Souris': 1, 'rue Pigalle': 1, 'Pigalle': 4, 'Y': 241, 'Clichy': 1, 'Montparnasse': 1, 'Pigalle\nY': 1, 'Voudrais': 1, 'Aimerais': 2, 'Fermé': 3, 'Libre': 7, 'Pouvoir': 3, 'Bousculant': 2, 'Jette': 1, 'O': 5, 'Amour\n': 1, 'Hhhhhan': 1, 'E': 16, "J'ai longtemps": 1, "J'crois": 5, "J'ai beau tourner": 1, 'Eux': 9, 'Où': 15, 'Saint-Cloud': 4, "Y'": 35, 'Villette\nJe sais': 1, 'Reviendront': 2, 'Ménilmontant': 1, 'Ramèneront': 1, 'Chanter': 4, "J'avais mon": 2, 'Mademoiselle': 6, 'Sois': 13, 'Ha': 2, 'Puis': 13, 'Les': 107, "J'ai": 2, 'Seront': 6, 'Notre': 7, 'Crois': 9, 'S': 24, 'A\nA': 1, 'Toi': 47, 'Vois': 13, 'Ca': 34, 'Tire': 2, 'Aussitôt': 2, 'Fera': 1, 'Te': 17, 'Cachera': 2, 'Sais': 3, 'Veux': 1, 'Bled': 1, 'Dessèchent': 1, 'Sanglants': 1, 'Dedans': 11, "J'ai pas peur des loups": 1, 'Croisant': 1, 'Emporte': 5, 'Arrache': 4, 'vis\n': 2, 'Puisque': 17, 'Serre-moi': 1, 'Revenir': 2, 'Misricorde': 5, 'Jean-Franois': 1, 'Pondais': 1, "J'ai vu deux amoureux\n": 1, 'Et constell?': 1, 'Marchaient': 1, 'Presque': 7, "J'en avais presque peur": 1, 'blas?s': 1, 'Nos h?ritiers': 1, 'Ecoutez': 6, 'Gare': 20, 'Peut-': 1, 'Tre': 5, 'Tr': 1, 'Voil': 1, 'Ponds': 1, 'Apporte': 3, 'Ton': 12, 'Pardonne': 3, 'Caresse': 1, 'Finis': 5, 'Saint-Pierre': 1, 'Serrée': 2, 'Je revois soudain\nQuand': 1, 'Mea Culpa!': 1, 'Culpa!': 1, 'Mea culpa': 2, 'Illuminée': 1, "J'ai vu ta bouche et je me sentais grise\n": 1, 'Berceau': 1, 'Mea culpa!': 2, "J'ai pêché les sept fois\nRien": 1, 'Cause': 6, 'Auprès': 10, 'Refrain': 1, 'Croque': 2, 'Gendes': 1, 'Finlande': 1, 'Aubervilliers': 1, 'Remplie': 1, 'Hurlant': 1, 'Laver': 1, 'Jour': 1, "J'ai beau fair' des?": 1, 'Comme': 5, "J'ai dit aux copains": 1, '’': 52, 'Eh ben': 2, 'Allez': 15, 'P': 5, 'Sumer': 1, 'Emplit': 1, 'Heureusement': 7, 'B': 12, 'Serai Orly': 2, 'Mexique': 2, 'Attendez': 2, 'Amour': 3, 'D?s': 2, 'Sire': 2, 'Séparons': 1, 'Louisiane\nJohn': 1, 'Travaille': 2, 'Lorsque soudain': 1, 'Ivre': 1, 'Bonsoir': 1, 'Ges': 1, 'Lectriques': 1, 'Re\nComme? A gazait': 1, 'Fallait': 11, 'Marseille': 31, 'Loin': 15, 'Es': 2, 'Blonds': 1, 'Faites': 2, 'Dansant': 1, 'Bac': 1, 'Regardez': 16, 'Russie': 1, 'Roulée': 1, 'Touchée': 1, 'Tourne': 4, 'Robe': 1, "J'ai dix-sept": 1, 'Joue': 3, 'Descend': 1, 'Hôtel de Russie': 3, 'aper?u': 1, 'Browning': 12, "Pris'": 1, 'France': 11,  ...

# %%
L= []

for lieu in lieux_en_commun:
  GR = freq1[lieu]/ freq2[lieu]
  L.append([GR, lieu])
for i in sorted(L):
  print(i)
# Out:
# [0.010452961672473868, 'A']
# [0.014084507042253521, 'Paris']
# [0.058823529411764705, 'Ca']
# [0.15384615384615385, 'Celles']
# [0.18181818181818182, 'France']
# [0.2, 'Venise']
# [0.3333333333333333, 'Amour']
# [0.5, 'Bordeaux']
# [1.0, 'Amsterdam']
# [1.0, 'Bornéo']
# [1.0, 'Créteil']
# [2.0, 'Varsovie']
